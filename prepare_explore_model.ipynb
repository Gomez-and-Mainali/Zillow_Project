# %%
import pandas as pd
import numpy as np
import acquire
import matplotlib.pyplot as plt
import seaborn as sns
import wrangle
from scipy import stats

# %% [markdown]
# **Lets acquire data using the get_data function from acquire module**

# %%
zillow = acquire.get_data()

# %% [markdown]
# **Lets take a look at our dataframe**

# %%
zillow.head()
# Out:
#         id  parcelid  bathroomcnt  bedroomcnt  calculatedbathnbr  \
# 0  2061546  11289917          2.0         3.0                2.0
# 1  1834372  11705026          1.0         2.0                1.0
# 2  1923117  14269464          3.0         4.0                3.0
# 3  2121349  11389003          2.0         3.0                2.0
# 4  2093710  11967869          1.0         2.0                1.0
#
#    regionidcounty  regionidzip  finishedsquarefeet12    fips  fullbathcnt  \
# 0          3101.0      97318.0                1458.0  6037.0          2.0
# 1          3101.0      96018.0                1421.0  6037.0          1.0
# 2          1286.0      96958.0                2541.0  6059.0          3.0
# 3          3101.0      96037.0                1650.0  6037.0          2.0
# 4          3101.0      96023.0                 693.0  6037.0          1.0
#
#    lotsizesquarefeet        propertylandusedesc transactiondate  taxamount  \
# 0             8284.0  Single Family Residential      2017-06-23    2319.90
# 1             6707.0  Single Family Residential      2017-06-30     543.69
# 2             4975.0  Single Family Residential      2017-06-01    9819.72
# 3             7300.0  Single Family Residential      2017-06-01    7673.19
# 4             2908.0  Single Family Residential      2017-06-29    3267.47
#
#    taxvaluedollarcnt
# 0           136104.0
# 1            35606.0
# 2           880456.0
# 3           614000.0
# 4           274237.0

# %% [markdown]
# **Getting some information about our data**

# %%
zillow.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15035 entries, 0 to 15034
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    15035 non-null  int64
#  1   parcelid              15035 non-null  int64
#  2   bathroomcnt           15035 non-null  float64
#  3   bedroomcnt            15035 non-null  float64
#  4   calculatedbathnbr     14989 non-null  float64
#  5   regionidcounty        15035 non-null  float64
#  6   regionidzip           15026 non-null  float64
#  7   finishedsquarefeet12  14968 non-null  float64
#  8   fips                  15035 non-null  float64
#  9   fullbathcnt           14989 non-null  float64
#  10  lotsizesquarefeet     14931 non-null  float64
#  11  propertylandusedesc   15035 non-null  object
#  12  transactiondate       15035 non-null  object
#  13  taxamount             15035 non-null  float64
#  14  taxvaluedollarcnt     15035 non-null  float64
# dtypes: float64(11), int64(2), object(2)
# memory usage: 1.7+ MB

# %% [markdown]
# **Takeaways:**
# - shape = 15035, 15
# - some null values
# - few object type that might need conversion

# %% [markdown]
# ## Preparation Phase

# %% [markdown]
# **Lets check for null values**

# %%
zillow.isnull().sum()
# Out:
# id                        0
# parcelid                  0
# bathroomcnt               0
# bedroomcnt                0
# calculatedbathnbr        46
# regionidcounty            0
# regionidzip               9
# finishedsquarefeet12     67
# fips                      0
# fullbathcnt              46
# lotsizesquarefeet       104
# propertylandusedesc       0
# transactiondate           0
# taxamount                 0
# taxvaluedollarcnt         0
# dtype: int64

# %% [markdown]
# **both fullbathcnt and calculatedbathnbr have 46 missing values, lets see if they are for same observations**

# %%
zillow.sort_values(by = 'calculatedbathnbr').tail(50)
# Out:
#             id   parcelid  bathroomcnt  bedroomcnt  calculatedbathnbr  \
# 6930   1510914   11655138          9.0         6.0                9.0
# 14423  2004396   11995760          9.0         7.0                9.0
# 12132  2731480   11095530         10.0        10.0               10.0
# 3868   1824424   11640165         11.0         7.0               11.0
# 5       496818   11696784          0.0         0.0                NaN
# 111    2323388   14252582          2.5         3.0                NaN
# 209    2434313   11392193          0.0         0.0                NaN
# 280    1071389   14466991          0.0         0.0                NaN
# 293    2776735   11266326          0.0         0.0                NaN
# 746    1735776   11938527          0.0         0.0                NaN
# 920     878996   13972530          0.0         0.0                NaN
# 921     819454   14325627          0.0         0.0                NaN
# 940    2946269   12686981          0.0         0.0                NaN
# 1741    355855   14507431          0.0         0.0                NaN
# 2629   2027525   12131538          0.0         0.0                NaN
# 2808    627032   17125199          0.0         4.0                NaN
# 3656   1035232   12153898          0.0         0.0                NaN
# 4096   2089168   17292027          0.0         0.0                NaN
# 4220   2291975   13836478          1.5         2.0                NaN
# 4879    530135   12554886          0.0         0.0                NaN
# 5552   2981687   14430787          0.0         0.0                NaN
# 6017   1070696   14248759          2.5         3.0                NaN
# 6171   1048411   11676853          0.0         0.0                NaN
# 6544   1081172   12444585          0.0         0.0                NaN
# 6584     60733   17267536          0.0         0.0                NaN
# 6941   1372384  167687839          0.0         0.0                NaN
# 8513   1902129   12528751          0.0         0.0                NaN
# 8956   2458209   14466726          0.0         0.0                NaN
# 9418   2296468   11679076          0.0         0.0                NaN
# 9602    602553   12055162          0.0         0.0                NaN
# 9796    580541   14326442          0.0         0.0                NaN
# 10963  1548327   14251525          1.5         5.0                NaN
# 11018   399754   14237996          0.0         0.0                NaN
# 11248  2594521   14359299          0.0         0.0                NaN
# 11543  1904742   13889651          0.0         0.0                NaN
# 11613  2427296   14144756          2.5         4.0                NaN
# 11847  2355346   13889433          0.0         0.0                NaN
# 12133  2560385   13865064          0.0         0.0                NaN
# 12304   281146   14469211          0.0         0.0                NaN
# 12516  2192051   11496648          0.0         0.0                NaN
# 12755  1070913   14312986          2.5         3.0                NaN
# 12924   283752   17105047          0.0         3.0                NaN
# 13258  1324032   14166728          0.0         0.0                NaN
# 13541   674466   11283520          0.0         0.0                NaN
# 13720  2610403   17237484          0.0         3.0                NaN
# 13790  1749638   11640641          0.0         0.0                NaN
# 13828  1983520   11486198          0.0         0.0                NaN
# 14505  2377279   12074776          0.0         0.0                NaN
# 14964  1238158   17061409          0.0         3.0                NaN
# 14977   170430   12179038          0.0         0.0                NaN
#
#        regionidcounty  regionidzip  finishedsquarefeet12    fips  fullbathcnt  \
# 6930           3101.0      96086.0               15450.0  6037.0          9.0
# 14423          3101.0      96017.0                7481.0  6037.0          9.0
# 12132          3101.0      96339.0                4294.0  6037.0         10.0
# 3868           3101.0      96086.0               11478.0  6037.0         11.0
# 5              3101.0      96024.0                1378.0  6037.0          NaN
# 111            1286.0      97006.0                   NaN  6059.0          NaN
# 209            3101.0      96024.0                2276.0  6037.0          NaN
# 280            1286.0      96989.0                   NaN  6059.0          NaN
# 293            3101.0      97319.0                 400.0  6037.0          NaN
# 746            3101.0      95993.0                 389.0  6037.0          NaN
# 920            1286.0      97004.0                   NaN  6059.0          NaN
# 921            1286.0      96975.0                   NaN  6059.0          NaN
# 940            3101.0      96121.0                   NaN  6037.0          NaN
# 1741           1286.0      96989.0                   NaN  6059.0          NaN
# 2629           3101.0      96278.0                   NaN  6037.0          NaN
# 2808           2061.0      97089.0                2945.0  6111.0          NaN
# 3656           3101.0      96271.0                 682.0  6037.0          NaN
# 4096           2061.0      96384.0                   NaN  6111.0          NaN
# 4220           1286.0      97006.0                   NaN  6059.0          NaN
# 4879           3101.0      96245.0                1064.0  6037.0          NaN
# 5552           1286.0      96961.0                   NaN  6059.0          NaN
# 6017           1286.0      97005.0                   NaN  6059.0          NaN
# 6171           3101.0      96126.0                 660.0  6037.0          NaN
# 6544           3101.0      96208.0                 738.0  6037.0          NaN
# 6584           2061.0      96351.0                   NaN  6111.0          NaN
# 6941           3101.0          NaN                   NaN  6037.0          NaN
# 8513           3101.0      96237.0                   NaN  6037.0          NaN
# 8956           1286.0      96989.0                   NaN  6059.0          NaN
# 9418           3101.0      96116.0                1820.0  6037.0          NaN
# 9602           3101.0      96320.0                   NaN  6037.0          NaN
# 9796           1286.0      96975.0                   NaN  6059.0          NaN
# 10963          1286.0      97001.0                   NaN  6059.0          NaN
# 11018          1286.0      97066.0                   NaN  6059.0          NaN
# 11248          1286.0      96952.0                   NaN  6059.0          NaN
# 11543          1286.0      96979.0                   NaN  6059.0          NaN
# 11613          1286.0      97043.0                   NaN  6059.0          NaN
# 11847          1286.0      96979.0                   NaN  6059.0          NaN
# 12133          1286.0      96966.0                   NaN  6059.0          NaN
# 12304          1286.0      96993.0                   NaN  6059.0          NaN
# 12516          3101.0      96124.0                   NaN  6037.0          NaN
# 12755          1286.0      96957.0                   NaN  6059.0          NaN
# 12924          2061.0      97119.0                2684.0  6111.0          NaN
# 13258          1286.0      97079.0                   NaN  6059.0          NaN
# 13541          3101.0      97317.0                 366.0  6037.0          NaN
# 13720          2061.0      97116.0                1092.0  6111.0          NaN
# 13790          3101.0      96086.0                   NaN  6037.0          NaN
# 13828          3101.0      96124.0                   NaN  6037.0          NaN
# 14505          3101.0      96327.0                 360.0  6037.0          NaN
# 14964          2061.0      97113.0                1760.0  6111.0          NaN
# 14977          3101.0      96284.0                   NaN  6037.0          NaN
#
#        lotsizesquarefeet        propertylandusedesc transactiondate  \
# 6930            165088.0  Single Family Residential      2017-05-31
# 14423             7425.0  Single Family Residential      2017-06-30
# 12132            16695.0  Single Family Residential      2017-06-22
# 3868             33617.0  Single Family Residential      2017-05-17
# 5                 7500.0  Single Family Residential      2017-06-16
# 111              18719.0  Single Family Residential      2017-05-01
# 209              10772.0  Single Family Residential      2017-05-01
# 280             105970.0  Single Family Residential      2017-05-01
# 293              55016.0  Single Family Residential      2017-05-01
# 746               7681.0  Single Family Residential      2017-05-03
# 920              13329.0  Single Family Residential      2017-05-04
# 921              20457.0  Single Family Residential      2017-05-04
# 940              30346.0  Single Family Residential      2017-05-04
# 1741             96141.0  Single Family Residential      2017-05-08
# 2629             10495.0  Single Family Residential      2017-05-11
# 2808             29631.0  Single Family Residential      2017-05-12
# 3656              4559.0  Single Family Residential      2017-05-17
# 4096            907790.0  Single Family Residential      2017-05-18
# 4220              8205.0  Single Family Residential      2017-05-19
# 4879              1993.0  Single Family Residential      2017-05-23
# 5552             11010.0  Single Family Residential      2017-05-25
# 6017             18637.0  Single Family Residential      2017-05-26
# 6171             24698.0  Single Family Residential      2017-05-26
# 6544              7000.0  Single Family Residential      2017-05-30
# 6584             12083.0  Single Family Residential      2017-05-30
# 6941                 NaN  Single Family Residential      2017-05-31
# 8513              2631.0  Single Family Residential      2017-06-06
# 8956            101287.0  Single Family Residential      2017-06-08
# 9418              6892.0  Single Family Residential      2017-06-12
# 9602             26369.0  Single Family Residential      2017-06-12
# 9796             14359.0  Single Family Residential      2017-06-13
# 10963             9661.0  Single Family Residential      2017-06-16
# 11018             7158.0  Single Family Residential      2017-06-16
# 11248                NaN  Single Family Residential      2017-06-19
# 11543             5338.0  Single Family Residential      2017-06-20
# 11613            26325.0  Single Family Residential      2017-06-20
# 11847             3482.0  Single Family Residential      2017-06-21
# 12133             6595.0  Single Family Residential      2017-06-22
# 12304             7056.0  Single Family Residential      2017-06-22
# 12516                NaN  Single Family Residential      2017-06-23
# 12755             8224.0  Single Family Residential      2017-06-23
# 12924           101059.0  Single Family Residential      2017-06-26
# 13258            21256.0  Single Family Residential      2017-06-27
# 13541            27369.0  Single Family Residential      2017-06-28
# 13720            20909.0  Single Family Residential      2017-06-28
# 13790            19837.0  Single Family Residential      2017-06-28
# 13828                NaN  Single Family Residential      2017-06-29
# 14505             2007.0  Single Family Residential      2017-06-30
# 14964            12200.0  Single Family Residential      2017-06-30
# 14977            42042.0  Single Family Residential      2017-06-30
#
#        taxamount  taxvaluedollarcnt
# 6930   121131.53         10071018.0
# 14423   43608.22          3617167.0
# 12132    8871.35           812200.0
# 3868   181533.24         15623925.0
# 5        2135.39           168828.0
# 111      2079.52           162456.0
# 209      1609.95           101792.0
# 280     25740.28          2493444.0
# 293       703.30            49627.0
# 746      4059.62           319396.0
# 920      3230.88           270009.0
# 921     81640.56          7074075.0
# 940     60905.26          5461875.0
# 1741    11761.22          1145602.0
# 2629     2736.14           225126.0
# 2808     1796.64           167510.0
# 3656      451.07            29361.0
# 4096    34159.22          3210155.0
# 4220     3112.70           236262.0
# 4879     2770.52           226328.0
# 5552    80251.50          5126781.0
# 6017     8604.04           735000.0
# 6171     8961.30           746757.0
# 6544     1337.61            84701.0
# 6584      302.94            26237.0
# 6941    22045.81          1842678.0
# 8513    15056.50          1289097.0
# 8956    16239.54          1558090.0
# 9418    12614.16          1034512.0
# 9602     4526.60           406100.0
# 9796    38260.82          3136161.0
# 10963    7565.48           635000.0
# 11018    6951.30           626497.0
# 11248   22416.08          1244873.0
# 11543    1339.68           125714.0
# 11613    1855.74           134264.0
# 11847   21343.18          1941143.0
# 12133   24296.84          2231097.0
# 12304   13389.68           970000.0
# 12516   11241.43           957014.0
# 12755    7261.74           665801.0
# 12924    1563.64           142838.0
# 13258   18203.58          1608894.0
# 13541     840.00            62030.0
# 13720    3215.32           256787.0
# 13790   25594.26          2077940.0
# 13828   10627.31           900820.0
# 14505     150.58            11089.0
# 14964     949.26            80303.0
# 14977    2182.49           177668.0

# %%
# turns out they are so we can drop these observations

zillow = zillow[~zillow.fullbathcnt.isna()]

# %%
zillow.isnull().sum()

# lets drop null observations for finishedsquarefeet12 columns

zillow = zillow[~zillow.finishedsquarefeet12.isna()]



#imputing value for lotsizesquare using mode, median or average will affect the data as they come out to be 
#higher so we will just drop them


zillow = zillow[~zillow.lotsizesquarefeet.isna()]

# %%
# lets drop observations with null values for regionidzip

zillow = zillow[~zillow.regionidzip.isna()]

# %%
zillow.isnull().sum()
# Out:
# id                      0
# parcelid                0
# bathroomcnt             0
# bedroomcnt              0
# calculatedbathnbr       0
# regionidcounty          0
# regionidzip             0
# finishedsquarefeet12    0
# fips                    0
# fullbathcnt             0
# lotsizesquarefeet       0
# propertylandusedesc     0
# transactiondate         0
# taxamount               0
# taxvaluedollarcnt       0
# dtype: int64

# %%
print(len(zillow))

print((zillow.bathroomcnt == zillow.calculatedbathnbr).sum())

# basically number of bathrooms and calculatedbathnbr mean the same thing so we can drop one of these column
# Out:
# 14849
# 14849

# %%
# since all of these observations are for single family home, and their transaction took place between the month of may and
# june of 2017. We can drop these columns. Also, they wont mean anything to our model and id is also not a significant columns for us



zillow = zillow.drop(columns = ['propertylandusedesc', 'fullbathcnt','transactiondate', 'parcelid', 'id', 'calculatedbathnbr'])

# %%
# renaming the column for more readeability

zillow = zillow.rename(columns = {'bathroomcnt':'numberofbathrooms', 'bedroomcnt':'numberofbedrooms', 
                         'regionidcounty':'countyid', 'regionidzip':'zipcode', 'finishedsquarefeet12':'size_in_squarefeet', 
                        'lotsizesquarefeet':'lotsize', 'taxamount': 'tax', 
                        'taxvaluedollarcnt':'property_value'})

# %%
zillow
# Out:
#        numberofbathrooms  numberofbedrooms  countyid  zipcode  \
# 0                    2.0               3.0    3101.0  97318.0
# 1                    1.0               2.0    3101.0  96018.0
# 2                    3.0               4.0    1286.0  96958.0
# 3                    2.0               3.0    3101.0  96037.0
# 4                    1.0               2.0    3101.0  96023.0
# ...                  ...               ...       ...      ...
# 15030                3.0               5.0    1286.0  97018.0
# 15031                3.0               5.0    1286.0  97067.0
# 15032                2.0               3.0    3101.0  96523.0
# 15033                3.0               5.0    1286.0  97065.0
# 15034                3.0               4.0    3101.0  96129.0
#
#        size_in_squarefeet    fips  lotsize      tax  property_value
# 0                  1458.0  6037.0   8284.0  2319.90        136104.0
# 1                  1421.0  6037.0   6707.0   543.69         35606.0
# 2                  2541.0  6059.0   4975.0  9819.72        880456.0
# 3                  1650.0  6037.0   7300.0  7673.19        614000.0
# 4                   693.0  6037.0   2908.0  3267.47        274237.0
# ...                   ...     ...      ...      ...             ...
# 15030              2526.0  6059.0   7800.0  5718.72        458903.0
# 15031              2735.0  6059.0   7100.0  1465.88        115387.0
# 15032              1536.0  6037.0   8818.0  3519.78        297097.0
# 15033              2655.0  6059.0   6000.0  8065.50        746963.0
# 15034              2305.0  6037.0   5742.0  6996.21        579047.0
#
# [14849 rows x 9 columns]

# %%
# trying to calulate the tax rate for these properties and creating a separate columns that stores the tax rate



zillow['tax_rate'] = (zillow.tax/zillow.property_value) * 100

zillow.sort_values(by = 'tax_rate', ascending = False)
# Out:
#        numberofbathrooms  numberofbedrooms  countyid  zipcode  \
# 9762                 1.0               2.0    3101.0  96023.0
# 1123                 1.0               3.0    2061.0  97089.0
# 3477                 2.0               3.0    3101.0  96361.0
# 7895                 2.0               3.0    3101.0  96523.0
# 5553                 2.0               3.0    3101.0  96486.0
# ...                  ...               ...       ...      ...
# 5312                 2.0               3.0    1286.0  96964.0
# 4539                 2.0               3.0    3101.0  96436.0
# 3403                 1.0               2.0    3101.0  96127.0
# 11026                3.0               3.0    3101.0  96030.0
# 9210                 3.0               4.0    2061.0  97104.0
#
#        size_in_squarefeet    fips  lotsize       tax  property_value  \
# 9762                572.0  6037.0   2968.0   9544.07         21074.0
# 1123               1504.0  6111.0  96658.0  17582.50         59629.0
# 3477               1186.0  6037.0   9464.0  13096.41         47163.0
# 7895               1754.0  6037.0  12027.0  11541.02         56697.0
# 5553               1488.0  6037.0   8451.0  24234.62        132742.0
# ...                   ...     ...      ...       ...             ...
# 5312               1185.0  6059.0   6250.0   1008.26        588818.0
# 4539               1372.0  6037.0   7560.0    120.84         81141.0
# 3403                936.0  6037.0   5750.0    963.15        866785.0
# 11026              2178.0  6037.0   6341.0   1928.38       1800000.0
# 9210               1781.0  6111.0   6452.0     51.26         65144.0
#
#         tax_rate
# 9762   45.288365
# 1123   29.486491
# 3477   27.768399
# 7895   20.355610
# 5553   18.256935
# ...          ...
# 5312    0.171235
# 4539    0.148926
# 3403    0.111118
# 11026   0.107132
# 9210    0.078687
#
# [14849 rows x 10 columns]

# %% [markdown]
# ### Takeaways:
# - The tax rate calculated using the tax amount and property value for some of these observations are way too high.Might be an outlier or inaccurate data.

# %%
# lets check if there are any outliers in our data


# plt.figure(figsize = (15,20))


for col in ['numberofbathrooms', 'numberofbedrooms', 'size_in_squarefeet', 'lotsize', 'tax', 'property_value']:
    plt.boxplot(zillow[col])
    plt.title(col)
    plt.show()
# plt.boxplot(zillow.property_value)
# plt.show()

# %% [markdown]
# ### Takeaways:
# - **All of the variables selected above(# of bathrooms, # of bedrooms, size in square feet, lotsize) have outliers**
# - **We will have to either remove all of these outliers or reduce them upto some extent**

# %%
plt.figure(figsize = (10,10))
sns.heatmap(zillow.corr(), cmap = 'Blues')
# Out:
# <AxesSubplot:>

# %%
sns.distplot(zillow.property_value)
# Out:
# <AxesSubplot:xlabel='property_value'>

# %%
# there are some outliers in the data. So, we will remove them 

q1 = zillow.property_value.quantile(0.25)
q3 = zillow.property_value.quantile(0.75)

iqr = q3-q1

upper_outlier_mark = q3 + (1.5 * iqr)

zillow = zillow[zillow.property_value < upper_outlier_mark]


zillow
# Out:
#        numberofbathrooms  numberofbedrooms  countyid  zipcode  \
# 0                    2.0               3.0    3101.0  97318.0
# 1                    1.0               2.0    3101.0  96018.0
# 2                    3.0               4.0    1286.0  96958.0
# 3                    2.0               3.0    3101.0  96037.0
# 4                    1.0               2.0    3101.0  96023.0
# ...                  ...               ...       ...      ...
# 15030                3.0               5.0    1286.0  97018.0
# 15031                3.0               5.0    1286.0  97067.0
# 15032                2.0               3.0    3101.0  96523.0
# 15033                3.0               5.0    1286.0  97065.0
# 15034                3.0               4.0    3101.0  96129.0
#
#        size_in_squarefeet    fips  lotsize      tax  property_value  tax_rate
# 0                  1458.0  6037.0   8284.0  2319.90        136104.0  1.704505
# 1                  1421.0  6037.0   6707.0   543.69         35606.0  1.526962
# 2                  2541.0  6059.0   4975.0  9819.72        880456.0  1.115299
# 3                  1650.0  6037.0   7300.0  7673.19        614000.0  1.249705
# 4                   693.0  6037.0   2908.0  3267.47        274237.0  1.191477
# ...                   ...     ...      ...      ...             ...       ...
# 15030              2526.0  6059.0   7800.0  5718.72        458903.0  1.246172
# 15031              2735.0  6059.0   7100.0  1465.88        115387.0  1.270403
# 15032              1536.0  6037.0   8818.0  3519.78        297097.0  1.184724
# 15033              2655.0  6059.0   6000.0  8065.50        746963.0  1.079772
# 15034              2305.0  6037.0   5742.0  6996.21        579047.0  1.208228
#
# [13860 rows x 10 columns]

# %%
zillow.groupby(zillow.fips).tax_rate.mean()
# Out:
# fips
# 6037.0    1.429358
# 6059.0    1.219247
# 6111.0    1.207982
# Name: tax_rate, dtype: float64

# %%
sns.boxplot(zillow.tax_rate)
# Out:
# <AxesSubplot:xlabel='tax_rate'>

# %%
sns.boxplot(zillow[zillow.tax_rate < 2.0].tax_rate)
# Out:
# <AxesSubplot:xlabel='tax_rate'>

# %%
sns.distplot(zillow.property_value)
# Out:
# <AxesSubplot:xlabel='property_value'>

# %%
sns.boxplot(zillow.property_value)
# Out:
# <AxesSubplot:xlabel='property_value'>

# %%
# lets get a count of the observations with different number of bathrooms and bedrooms

print(zillow.numberofbedrooms.value_counts())
print()
print(zillow.numberofbathrooms.value_counts())
# Out:
# 3.0     6369
# 4.0     4022
# 2.0     2252
# 5.0      909
# 1.0      160
# 6.0      126
# 7.0       17
# 0.0        2
# 11.0       1
# 10.0       1
# 8.0        1
# Name: numberofbedrooms, dtype: int64
#
# 2.0     6035
# 3.0     2900
# 1.0     2576
# 2.5     1128
# 4.0      474
# 3.5      234
# 1.5      234
# 4.5      120
# 5.0      114
# 6.0       20
# 5.5       16
# 7.0        4
# 8.0        3
# 9.0        1
# 10.0       1
# Name: numberofbathrooms, dtype: int64

# %%
# lets get rid of some of the outliers

zillow = zillow[zillow.numberofbedrooms<7]

zillow = zillow[zillow.numberofbathrooms < 6]

zillow = zillow[zillow.numberofbedrooms!=0]

# %%
# lets take a look with boxplot

sns.boxplot(zillow.numberofbathrooms)
plt.show()

sns.boxplot(zillow.numberofbedrooms)
plt.show()

# %% [markdown]
# ### Takeaway:
# - Our boxplot looks much better. We are keeping rest of the values for better representation

# %% [markdown]
# #### We can get the fips information from following website
# #### https://transition.fcc.gov/oet/info/maps/census/fips/fips.txt
# so,
#
# 6037: LA,
#
# 6059: Orange,
#
# 6111: Ventura
#
# ### we will replace fips with these values

# %%
zillow
# Out:
#        numberofbathrooms  numberofbedrooms  countyid  zipcode  \
# 0                    2.0               3.0    3101.0  97318.0
# 1                    1.0               2.0    3101.0  96018.0
# 2                    3.0               4.0    1286.0  96958.0
# 3                    2.0               3.0    3101.0  96037.0
# 4                    1.0               2.0    3101.0  96023.0
# ...                  ...               ...       ...      ...
# 15030                3.0               5.0    1286.0  97018.0
# 15031                3.0               5.0    1286.0  97067.0
# 15032                2.0               3.0    3101.0  96523.0
# 15033                3.0               5.0    1286.0  97065.0
# 15034                3.0               4.0    3101.0  96129.0
#
#        size_in_squarefeet    fips  lotsize      tax  property_value  tax_rate
# 0                  1458.0  6037.0   8284.0  2319.90        136104.0  1.704505
# 1                  1421.0  6037.0   6707.0   543.69         35606.0  1.526962
# 2                  2541.0  6059.0   4975.0  9819.72        880456.0  1.115299
# 3                  1650.0  6037.0   7300.0  7673.19        614000.0  1.249705
# 4                   693.0  6037.0   2908.0  3267.47        274237.0  1.191477
# ...                   ...     ...      ...      ...             ...       ...
# 15030              2526.0  6059.0   7800.0  5718.72        458903.0  1.246172
# 15031              2735.0  6059.0   7100.0  1465.88        115387.0  1.270403
# 15032              1536.0  6037.0   8818.0  3519.78        297097.0  1.184724
# 15033              2655.0  6059.0   6000.0  8065.50        746963.0  1.079772
# 15034              2305.0  6037.0   5742.0  6996.21        579047.0  1.208228
#
# [13814 rows x 10 columns]

# %%
zillow.fips = zillow.fips.astype(int)



zillow = zillow.replace({'fips':{6037: 'LA', 6059: 'Orange', 6111: 'Ventura'}})

zillow = zillow.rename(columns = {'fips': 'County'})
zillow
# Out:
#        numberofbathrooms  numberofbedrooms  countyid  zipcode  \
# 0                    2.0               3.0    3101.0  97318.0
# 1                    1.0               2.0    3101.0  96018.0
# 2                    3.0               4.0    1286.0  96958.0
# 3                    2.0               3.0    3101.0  96037.0
# 4                    1.0               2.0    3101.0  96023.0
# ...                  ...               ...       ...      ...
# 15030                3.0               5.0    1286.0  97018.0
# 15031                3.0               5.0    1286.0  97067.0
# 15032                2.0               3.0    3101.0  96523.0
# 15033                3.0               5.0    1286.0  97065.0
# 15034                3.0               4.0    3101.0  96129.0
#
#        size_in_squarefeet  County  lotsize      tax  property_value  tax_rate
# 0                  1458.0      LA   8284.0  2319.90        136104.0  1.704505
# 1                  1421.0      LA   6707.0   543.69         35606.0  1.526962
# 2                  2541.0  Orange   4975.0  9819.72        880456.0  1.115299
# 3                  1650.0      LA   7300.0  7673.19        614000.0  1.249705
# 4                   693.0      LA   2908.0  3267.47        274237.0  1.191477
# ...                   ...     ...      ...      ...             ...       ...
# 15030              2526.0  Orange   7800.0  5718.72        458903.0  1.246172
# 15031              2735.0  Orange   7100.0  1465.88        115387.0  1.270403
# 15032              1536.0      LA   8818.0  3519.78        297097.0  1.184724
# 15033              2655.0  Orange   6000.0  8065.50        746963.0  1.079772
# 15034              2305.0      LA   5742.0  6996.21        579047.0  1.208228
#
# [13814 rows x 10 columns]

# %% [markdown]
# # Lets get the distribution of tax rate for each county

# %%
la =zillow[zillow.County == "LA"]

orange = zillow[zillow.County == "Orange"]

ventura = zillow[zillow.County == "Ventura"]

# %%
print(la.tax_rate.describe())
print()

print(orange.tax_rate.describe())
print()

print(ventura.tax_rate.describe())
# Out:
# count    8843.000000
# mean        1.430064
# std         0.777878
# min         0.111118
# 25%         1.218898
# 50%         1.276117
# 75%         1.464309
# max        45.288365
# Name: tax_rate, dtype: float64
#
# count    3716.000000
# mean        1.217725
# std         0.316226
# min         0.171235
# 25%         1.070868
# 50%         1.157975
# 75%         1.258951
# max        10.735031
# Name: tax_rate, dtype: float64
#
# count    1255.000000
# mean        1.208168
# std         0.840354
# min         0.078687
# 25%         1.074545
# 50%         1.127278
# 75%         1.193874
# max        29.486491
# Name: tax_rate, dtype: float64

# %% [markdown]
# ### Takeaways:
# - There are few outliers in tax rate. There are values that are just extremely high or low to be real

# %%
# removing the outliers for the tax in la county because there are extremely low and there are extremely high tax rate

la = la[la.tax_rate.between(la.tax_rate.quantile(.05), la.tax_rate.quantile(.95))]


orange = orange[orange.tax_rate.between(orange.tax_rate.quantile(.05), orange.tax_rate.quantile(.95))]


ventura = ventura[ventura.tax_rate.between(ventura.tax_rate.quantile(.05), ventura.tax_rate.quantile(.95))]

# lets plot the distribution of the tax rate in la county
plt.figure(figsize = (10,10))


sns.distplot(la.tax_rate, color ='blue', label = 'LA County')

sns.distplot(orange.tax_rate, color = 'green', label = 'Orange County')

sns.distplot(ventura.tax_rate, color = 'red', label = 'Ventura County')

plt.title('How is tax distributed in each county?')

plt.legend()

plt.show()

# %% [markdown]
# ### Takeaways:
# - Tax rate in LA county is much higher than Orange and Ventura county
# - More properties are in LA county

# %% [markdown]
# ### Lets check the average property value in each county

# %%
zillow.groupby(zillow.County).property_value.mean().plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='County'>

# %% [markdown]
# **Hypothesis**
#
# **County influences home value**
#
# $H_0$: There is no relationship between County and home value
#
# $H_a$: County influences home value
#
# $a$: 0.05

# %%
# Since we are comparing a categorical and continuous variable, we must use T-test to compare the mean home values
# of different counties

a = 0.05


# from the vizualization above, we can see the home value in LA county is significantly lower, so we will compare the
# mean home value between la county and not la county

x1 = zillow[zillow.County =='LA'].property_value

x2 = zillow[zillow.County !='LA'].property_value


t, p = stats.ttest_ind(x1, x2)

t, p

if (t < 0) and (p < a):
    print('We reject the null hypothesis and the home value in LA county are significantly lower than other counties')
else:
    print('We fail to reject the null hypothesis')
# Out:
# We reject the null hypothesis and the home value in LA county are significantly lower than other counties

# %%
dummies = pd.get_dummies(zillow.County)

# %%
zillow = pd.concat([zillow, dummies], axis = 1)

# %%
zillow = zillow.drop(columns = 'County')

# %%
zillow.sort_values(by = 'numberofbedrooms', ascending = True)
# Out:
#        numberofbathrooms  numberofbedrooms  countyid  zipcode  \
# 13027                1.0               1.0    3101.0  96238.0
# 9182                 1.0               1.0    3101.0  95984.0
# 11865                1.0               1.0    3101.0  96025.0
# 4373                 2.0               1.0    1286.0  96958.0
# 6054                 2.0               1.0    3101.0  96162.0
# ...                  ...               ...       ...      ...
# 8223                 5.0               6.0    3101.0  96349.0
# 12137                2.5               6.0    2061.0  97089.0
# 8880                 5.0               6.0    3101.0  96492.0
# 3005                 5.0               6.0    3101.0  96030.0
# 2451                 3.0               6.0    3101.0  97319.0
#
#        size_in_squarefeet  lotsize       tax  property_value  tax_rate  LA  \
# 13027               624.0   2024.0   3244.62        261934.0  1.238717   1
# 9182                768.0   5005.0    603.97         40737.0  1.482608   1
# 11865               624.0   5805.0    343.43         19476.0  1.763350   1
# 4373               1244.0   1400.0   2324.52        166328.0  1.397552   0
# 6054                850.0   5577.0   1395.58        108972.0  1.280678   1
# ...                   ...      ...       ...             ...       ...  ..
# 8223               4404.0  17502.0   7329.71        579415.0  1.265019   1
# 12137              2878.0   7000.0   3787.70        355253.0  1.066198   0
# 8880               3551.0  11135.0  17667.34       1154659.0  1.530092   1
# 3005               4160.0  10066.0  12535.28       1024722.0  1.223286   1
# 2451               2818.0   6608.0   4866.60        328000.0  1.483720   1
#
#        Orange  Ventura
# 13027       0        0
# 9182        0        0
# 11865       0        0
# 4373        1        0
# 6054        0        0
# ...       ...      ...
# 8223        0        0
# 12137       0        1
# 8880        0        0
# 3005        0        0
# 2451        0        0
#
# [13814 rows x 12 columns]

# %%
zillow = zillow.drop(columns = 'tax_rate')


train, test, validate = wrangle.split_data(zillow)

# %%
train.shape, test.shape, validate.shape

train
# Out:
#        numberofbathrooms  numberofbedrooms  countyid  zipcode  \
# 4038                 3.0               5.0    3101.0  96522.0
# 2680                 3.0               4.0    3101.0  96330.0
# 7189                 2.0               3.0    1286.0  96180.0
# 185                  2.0               2.0    3101.0  96020.0
# 11121                1.0               2.0    3101.0  95983.0
# ...                  ...               ...       ...      ...
# 6815                 2.0               3.0    3101.0  96411.0
# 7417                 2.0               3.0    3101.0  96514.0
# 7134                 2.0               3.0    3101.0  96494.0
# 9072                 2.5               3.0    1286.0  96962.0
# 14771                1.0               3.0    2061.0  97081.0
#
#        size_in_squarefeet  lotsize      tax  property_value  LA  Orange  \
# 4038               2100.0  10630.0  6751.58        570278.0   1       0
# 2680               2235.0  12562.0  5586.33        497836.0   1       0
# 7189               1192.0   7590.0  2482.10        201476.0   0       1
# 185                1895.0   5741.0  6534.81        542048.0   1       0
# 11121               864.0   6752.0  2449.26        176181.0   1       0
# ...                   ...      ...      ...             ...  ..     ...
# 6815               1602.0   8947.0  3915.11        312068.0   1       0
# 7417               1459.0   5921.0  4419.92        348727.0   1       0
# 7134               1412.0   7960.0  5694.34        488654.0   1       0
# 9072               2022.0   6200.0  3825.68        370137.0   0       1
# 14771              1124.0   4747.0  4029.40        376000.0   0       0
#
#        Ventura
# 4038         0
# 2680         0
# 7189         0
# 185          0
# 11121        0
# ...        ...
# 6815         0
# 7417         0
# 7134         0
# 9072         0
# 14771        1
#
# [8840 rows x 11 columns]

# %% [markdown]
# ## Exploration Phase

# %%
plt.figure(figsize = (15,15))

sns.pairplot(train)

# %%
# lets plot a heat map of the correlation


plt.figure(figsize = (15,15))

sns.heatmap(train.drop(columns = [ 'tax']).corr(), cmap = 'Blues', annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Takeaways:
# - We can see a strong correlation between property value and full bath count, size in square feet, number of bathrooms, and number of bedrooms

# %% [markdown]
# ### Hypothesis
#
# **1. size of the single family unit in square feet affect the price of the property**
#
# - both of these variables are continuous so, we must conduct pearson r hypothesis test
#
# $H_0$: The size in square feet and the price of the property are independent of each other
#
# $H_a$: The size in square feet and the price of the property are dependent of each other

# %%
from scipy import stats

# %%
# setting our significance level

a = 0.05

r, p = stats.pearsonr(train.size_in_squarefeet, train.property_value)

r, p
# Out:
# (0.5309019048069188, 0.0)

# %%
if p < a:
    print("We reject the null hypothesis")
else:
    print('we fail to reject the null hypothesis')
# Out:
# We reject the null hypothesis

# %% [markdown]
# ### Takeaways:
# - our p is low so we reject the null hypothesis that size in square feet and property value are independent of each other
# - our r value os 0.53, indicating a correlation

# %%
train.groupby(train.numberofbathrooms).property_value.mean().plot()
# Out:
# <AxesSubplot:xlabel='numberofbathrooms'>

# %%
train.groupby(train.numberofbedrooms).property_value.mean().plot()
# Out:
# <AxesSubplot:xlabel='numberofbedrooms'>

# %% [markdown]
# ### Takeaways:
#
# **the number of bedrooms almost has a linear relationship with home values**
#
# **the number of bathrooms almost has a linear relationship with  home values**

# %% [markdown]
# ## Modeling
# **Lets scale the data first**

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
train.numberofbathrooms.value_counts()
# Out:
# 2.0    3883
# 3.0    1789
# 1.0    1662
# 2.5     721
# 4.0     312
# 3.5     156
# 1.5     149
# 5.0      85
# 4.5      74
# 5.5       9
# Name: numberofbathrooms, dtype: int64

# %%
train.numberofbedrooms.value_counts()
# Out:
# 3.0    4032
# 4.0    2559
# 2.0    1478
# 5.0     581
# 1.0     105
# 6.0      85
# Name: numberofbedrooms, dtype: int64

# %%
x_train = train.drop(columns = ['tax', 'property_value'])
y_train = train[['property_value']]

x_validate = validate.drop(columns = ['tax', 'property_value'])
y_validate = validate[['property_value']]


x_test = test.drop(columns = ['tax', 'property_value'])
y_test = test[['property_value']]

# %%
scaler = MinMaxScaler()

cols_to_scale = x_train.columns

x_train_scaled, x_test_scaled, x_validate_scaled = wrangle.scale_data(x_train, x_test, x_validate, scaler = scaler,
                                                                      cols_to_scale = cols_to_scale)

# %%
x_train_scaled
# Out:
#        numberofbathrooms_scaled  numberofbedrooms_scaled  countyid_scaled  \
# 4038                   0.444444                      0.8         1.000000
# 2680                   0.444444                      0.6         1.000000
# 7189                   0.222222                      0.4         0.000000
# 185                    0.222222                      0.2         1.000000
# 11121                  0.000000                      0.2         1.000000
# ...                         ...                      ...              ...
# 6815                   0.222222                      0.4         1.000000
# 7417                   0.222222                      0.4         1.000000
# 7134                   0.222222                      0.4         1.000000
# 9072                   0.333333                      0.4         0.000000
# 14771                  0.000000                      0.4         0.426997
#
#        zipcode_scaled  size_in_squarefeet_scaled  lotsize_scaled  LA_scaled  \
# 4038         0.001778                   0.278810        0.008990        1.0
# 2680         0.001146                   0.299721        0.010728        1.0
# 7189         0.000652                   0.138166        0.006254        0.0
# 185          0.000125                   0.247057        0.004590        1.0
# 11121        0.000003                   0.087361        0.005500        1.0
# ...               ...                        ...             ...        ...
# 6815         0.001413                   0.201673        0.007475        1.0
# 7417         0.001752                   0.179523        0.004752        1.0
# 7134         0.001686                   0.172243        0.006587        1.0
# 9072         0.003227                   0.266729        0.005003        0.0
# 14771        0.003619                   0.127633        0.003696        0.0
#
#        Orange_scaled  Ventura_scaled
# 4038             0.0             0.0
# 2680             0.0             0.0
# 7189             1.0             0.0
# 185              0.0             0.0
# 11121            0.0             0.0
# ...              ...             ...
# 6815             0.0             0.0
# 7417             0.0             0.0
# 7134             0.0             0.0
# 9072             1.0             0.0
# 14771            0.0             1.0
#
# [8840 rows x 9 columns]

# %%
print(train[train.LA == 1].property_value.median())

print(train[train.Orange == 1].property_value.median())

print(train[train.Ventura == 1].property_value.median())
# Out:
# 297976.0
# 456247.0
# 440165.0

# %% [markdown]
# ### Lets build model

# %%
from sklearn.metrics import mean_squared_error, explained_variance_score
from sklearn.linear_model import LinearRegression, LassoLars
from sklearn.preprocessing import PolynomialFeatures

from sklearn.feature_selection import RFE

# %% [markdown]
# ### Baseline First

# %%
y_train.median()
# Out:
# property_value    351070.0
# dtype: float64

# %%
## we will use the median as our baseline

baseline = y_train.median()


# predicting using our baseline
y_baseline_pred = np.full(len(y_train), baseline)

baseline_rmse = (mean_squared_error(y_train, y_baseline_pred)) ** (1/2)

baseline_rmse
# Out:
# 286498.8581858487

# %%
x_vars = x_train_scaled[['numberofbathrooms_scaled', 'numberofbedrooms_scaled', 'size_in_squarefeet_scaled']]

x_vars
# Out:
#        numberofbathrooms_scaled  numberofbedrooms_scaled  \
# 4038                   0.444444                      0.8
# 2680                   0.444444                      0.6
# 7189                   0.222222                      0.4
# 185                    0.222222                      0.2
# 11121                  0.000000                      0.2
# ...                         ...                      ...
# 6815                   0.222222                      0.4
# 7417                   0.222222                      0.4
# 7134                   0.222222                      0.4
# 9072                   0.333333                      0.4
# 14771                  0.000000                      0.4
#
#        size_in_squarefeet_scaled
# 4038                    0.278810
# 2680                    0.299721
# 7189                    0.138166
# 185                     0.247057
# 11121                   0.087361
# ...                          ...
# 6815                    0.201673
# 7417                    0.179523
# 7134                    0.172243
# 9072                    0.266729
# 14771                   0.127633
#
# [8840 rows x 3 columns]

# %% [markdown]
# ## Modeling with only three selected features

# %% [markdown]
# ### Linear Regression Model

# %%
# create the object

lm = LinearRegression(normalize = True)

# fit the object
lm = lm.fit(x_vars, y_train)

# predict with the object

y_lm_pred = lm.predict(x_vars)

# calcualte the RMSE

lm_rmse = (mean_squared_error(y_train, y_lm_pred)) **(1/2)

lm_rmse
# Out:
# 236134.15069726598

# %%
xvs_lm = explained_variance_score(y_train, y_lm_pred)
xvs_lm
# Out:
# 0.2955204044762191

# %% [markdown]
# ### LassoLars

# %%
# create the object
lars = LassoLars(alpha = 0)


# fit the object
lars = lars.fit(x_vars, y_train)


# predict with the object
y_lars_pred = lars.predict(x_vars)


# calculate the rmse
lars_rmse = (mean_squared_error(y_train, y_lars_pred)) **(1/2)

lars_rmse
# Out:
# 236134.15069726598

# %%
xvs_lars = explained_variance_score(y_train, y_lars_pred)
xvs_lars
# Out:
# 0.2955204044762191

# %% [markdown]
# ### Polynomial + Linear Reg

# %%
# lets try polynomial features with linear regression


# create polynomial object
pf = PolynomialFeatures(degree = 2)

# fitting the object
pf = pf.fit(x_vars)


# transforming our training data set
x_vars_squared = pf.transform(x_vars)



# lets get the Linear Regression

lm_squared = LinearRegression()


# fit the linear regression object

lm_squared = lm_squared.fit(x_vars_squared, y_train)

#predict with the object

y_lm_squared_pred = lm_squared.predict(x_vars_squared)


# lets get rmse

lm_squared_rmse = (mean_squared_error(y_train, y_lm_squared_pred)) **(1/2)

lm_squared_rmse
# Out:
# 235571.25701520618

# %%
xvs_lm_squared = explained_variance_score(y_train, y_lm_squared_pred)
xvs_lm_squared
# Out:
# 0.2988750608884888

# %% [markdown]
# ### RMSE for different algorithms

# %%
print(f'The Baseline RMSE: {baseline_rmse}')
print(f'The Linear model  RMSE: {lm_rmse}')
print(f'The LassoLars RMSE: {lars_rmse}')
print(f'The Polynomial features RMSE: {lm_squared_rmse}')
# Out:
# The Baseline RMSE: 286498.8581858487
# The Linear model  RMSE: 236134.15069726598
# The LassoLars RMSE: 236134.15069726598
# The Polynomial features RMSE: 235571.25701520618

# %%
# lets try to plot these values

plt.figure(figsize = (12,12))
plt.scatter(y_train, y_baseline_pred, label = 'baseline')

plt.scatter(y_train, y_lm_pred, label = 'linear model')

plt.scatter(y_train, y_lars_pred, label = 'lassolars')


plt.scatter(y_train, y_lm_squared_pred, label = 'polynomial features')

plt.plot([0, 1600000], [0, 1600000], ls = "-" , c = 'black', label = 'Perfect prediction')

plt.xlabel("Actual")

plt.ylabel("Predicted")

plt.title('Actual Vs Predicted')

plt.legend()

plt.show()

# %% [markdown]
# ## We will run all the models we created using three variables through our validate data.

# %%
# Validating with linear regression model
y_validate = validate[['property_value']]


x_validate_vars = x_validate_scaled[['numberofbathrooms_scaled', 'numberofbedrooms_scaled', 
                                     'size_in_squarefeet_scaled']]

y_validate_lm_pred = lm.predict(x_validate_vars)


val_lm_rmse = (mean_squared_error(y_validate, y_validate_lm_pred)) ** (1/2)

val_lm_rmse
# Out:
# 235086.51599159447

# %%
# validate with lassolars

y_validate_lars_pred = lars.predict(x_validate_vars)


val_lars_rmse = (mean_squared_error(y_validate, y_validate_lars_pred)) ** (1/2)

val_lars_rmse
# Out:
# 235086.51599159447

# %%
# lets try polynomial features with linear regression





# transforming our validate data set
x_val_vars_squared = pf.transform(x_validate_vars)










#predict with the object

y_val_lm_squared_pred = lm_squared.predict(x_val_vars_squared)


# lets get rmse

lm_squared_val_rmse = (mean_squared_error(y_validate, y_val_lm_squared_pred)) **(1/2)

lm_squared_val_rmse
# Out:
# 234729.33978092275

# %%
xvs_val = explained_variance_score(y_validate, y_val_lm_squared_pred )

xvs_val
# Out:
# 0.2863685425276734

# %%
print(f'The Baseline RMSE: {baseline_rmse}')
print(f'The Linear model  RMSE: {val_lm_rmse}')
print(f'The LassoLars RMSE: {val_lars_rmse}')
print(f'The Polynomial features RMSE: {lm_squared_val_rmse}')
# Out:
# The Baseline RMSE: 286498.8581858487
# The Linear model  RMSE: 235086.51599159447
# The LassoLars RMSE: 235086.51599159447
# The Polynomial features RMSE: 234729.33978092275

# %% [markdown]
# ## Our polynomial feature + linear reg model with 2nd degree performed better with our validate data
# **So we will use this to run on our test data**

# %%
y_test = test[['property_value']]


x_test_vars = x_test_scaled[['numberofbathrooms_scaled', 'numberofbedrooms_scaled', 
                                     'size_in_squarefeet_scaled']]

# %%
# transforming our validate data set
x_test_vars_squared = pf.transform(x_test_vars)










#predict with the object

y_test_lm_squared_pred = lm_squared.predict(x_test_vars_squared)


# lets get rmse

lm_squared_test_rmse = (mean_squared_error(y_test, y_test_lm_squared_pred)) **(1/2)

lm_squared_test_rmse
# Out:
# 232813.9185215822

# %%
xvs_lm_squared_test = explained_variance_score(y_test, y_test_lm_squared_pred )
xvs_lm_squared_test
# Out:
# 0.3099121723968038

# %%
print(f'The Baseline RMSE: {baseline_rmse}')
print()
print(f'The Polynomial features RMSE for test data: {lm_squared_test_rmse}')
# Out:
# The Baseline RMSE: 286498.8581858487
#
# The Polynomial features RMSE for test data: 232813.9185215822

# %% [markdown]
# ## Polynomial Features model performed well with test data and performed much better than the baseline model

# %% [markdown]
# # Modeling with all the variables except countyid_scaled and zipcode_scaled
# ## Linear Regression

# %%
x_train_scaled = x_train_scaled.drop(columns = ['countyid_scaled', 'zipcode_scaled'])

# create the object

lm2 = LinearRegression(normalize = True)


# fit the object

lm2 = lm2.fit(x_train_scaled, y_train)


# predict with the object

y_lm2_pred = lm2.predict(x_train_scaled)


# rmse

lm2_rmse = (mean_squared_error(y_train, y_lm2_pred)) **(1/2)

print('RMSE:', lm2_rmse)

xvs_lm2 = explained_variance_score(y_train, y_lm2_pred)
print('Explained_Variance:' , xvs_lm2)
# Out:
# RMSE: 234151.6734472179
# Explained_Variance: 0.3073007349476863

# %% [markdown]
# ## LassoLars

# %%
# create the object
lars2 = LassoLars(alpha = 0)


# fit the object
lars2 = lars2.fit(x_train_scaled, y_train)


# predict with the object
y_lars2_pred = lars2.predict(x_train_scaled)


# calculate the rmse
lars2_rmse = (mean_squared_error(y_train, y_lars2_pred)) **(1/2)

print('Lars_RMSE:', lars2_rmse)

xvs_lars2 = explained_variance_score(y_train, y_lars2_pred)

print('Lars_explained_variance:', xvs_lars2)
# Out:
# Lars_RMSE: 234142.74024415205
# Lars_explained_variance: 0.307352597269149

# %% [markdown]
# ## Polynomial Features + Linear Reg

# %%
# create polynomial object
pf2 = PolynomialFeatures(degree = 2)

# fitting the object
pf2 = pf2.fit(x_train_scaled)


# transforming our training data set
x_train_scaled_squared = pf2.transform(x_train_scaled)



# lets get the Linear Regression

lm_squared2 = LinearRegression()


# fit the linear regression object

lm_squared2 = lm_squared2.fit(x_train_scaled_squared, y_train)

#predict with the object

y_lm_squared2_pred = lm_squared2.predict(x_train_scaled_squared)


# lets get rmse

lm_squared2_rmse = (mean_squared_error(y_train, y_lm_squared2_pred)) **(1/2)

print('Polynomial RMSE:', lm_squared2_rmse)


xvs_lm_squared2 = explained_variance_score(y_train, y_lm_squared2_pred)

print('Polynomia_explained_variance:', xvs_lm_squared2)
# Out:
# Polynomial RMSE: 232000.24018964884
# Polynomia_explained_variance: 0.31998202288498256

# %%
# lets try to plot these values

plt.figure(figsize = (12,12))
plt.scatter(y_train, y_baseline_pred, label = 'baseline')

plt.scatter(y_train, y_lm2_pred, label = 'linear model')

plt.scatter(y_train, y_lars2_pred, label = 'lassolars')


plt.scatter(y_train, y_lm_squared2_pred, label = 'polynomial features')

plt.plot([0, 1600000], [0, 1600000], ls = "-" , c = 'black', label = 'Perfect prediction')

plt.xlabel("Actual")

plt.ylabel("Predicted")

plt.title('Actual Vs Predicted')

plt.legend()

plt.show()

# %% [markdown]
# ## Lets Validate with all models

# %% [markdown]
# ### Linear Regression

# %%
x_validate_scaled = x_validate_scaled.drop(columns = ['countyid_scaled', 'zipcode_scaled'])

# predict with the object
y_lm_val_pred = lm2.predict(x_validate_scaled)


lm_val_rmse = (mean_squared_error(y_validate, y_lm_val_pred)) **(1/2)

print('Lm_validate_RMSE:', lm_val_rmse)
# Out:
# Lm_validate_RMSE: 233793.94968555955

# %% [markdown]
# ### LassoLars

# %%
# predict with the object
y_lars_val_pred = lars2.predict(x_validate_scaled)


lars_val_rmse = (mean_squared_error(y_validate, y_lars_val_pred)) **(1/2)

print('Lars_validate_RMSE:', lars_val_rmse)
# Out:
# Lars_validate_RMSE: 233757.86289472334

# %% [markdown]
# ### Ploynomial Features

# %%
# transform with the object
x_validate_scaled_squared = pf2.transform(x_validate_scaled)


# predict with the object

y_lm_squared_val_pred = lm_squared2.predict(x_validate_scaled_squared)


lm_squared_val_rmse = (mean_squared_error(y_validate, y_lm_squared_val_pred)) **(1/2)

print('Lm_squared_validate_RMSE:',lm_squared_val_rmse )
# Out:
# Lm_squared_validate_RMSE: 232326.40636236753

# %% [markdown]
# ## Our polynomial features of second degree performed better compared to other models. So, we will use this model with our test data

# %%
x_test_scaled = x_test_scaled.drop(columns = ['countyid_scaled', 'zipcode_scaled'])

# transforming our x variables
x_test_scaled_squared = pf2.transform(x_test_scaled)


# predicting with our object

y_lm_squared_test_pred2 = lm_squared2.predict(x_test_scaled_squared)


# calculating our RMSE
lm_squared_test2_rmse = (mean_squared_error(y_test, y_lm_squared_test_pred2)) **(1/2)


print('Lm_squared_test_RMSE with all but 2 features:', lm_squared_test2_rmse)
print()
print('Our baseline RMSE: ', baseline_rmse)
# Out:
# Lm_squared_test_RMSE with all but 2 features: 230981.58662843154
#
# Our baseline RMSE:  286498.8581858487

# %% [markdown]
# **Our model performed better than the baseline with test data.**

# %%
print('Test Rmse of a model with just three features # of bathroom, # of bedroom, and size in sq feet:', lm_squared_test_rmse)
print()
print('Test Rmse of a model with all but 2 features zipcode and county id:', lm_squared_test2_rmse )
# Out:
# Test Rmse of a model with just three features # of bathroom, # of bedroom, and size in sq feet: 232813.9185215822
#
# Test Rmse of a model with all but 2 features zipcode and county id: 230981.58662843154

# %%
plt.figure(figsize= (10,10))

plt.scatter(y_test, y_test_lm_squared_pred, label = 'model with  3 features', color = 'red')

plt.scatter(y_test, y_lm_squared_test_pred2, label = 'model with all but 2 features', color = 'blue')

plt.plot([0, 1600000], [0, 1600000], ls = ":" , c = 'black', label = 'Perfect prediction')


plt.legend()
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual Vs Predicted')

plt.show()

# %% [markdown]
# ## Takeaways:
# - Model created using all the features except countryid and zipcodeid did better than the model with three features(# of bedroom, # of bathroom, and squarefeet).
# - We can see the predicted value using these models above
